# %% [markdown]
# # Aristotle logic

# %% [markdown]
# ## boolians

# %%
1 < 6 or 1.5 > 0
# Out:
# True

# %%
1 < 6/7 or 1.5 > 0 + 7
# Out:
# False

# %% [markdown]
# ## Strings

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
'Hello ' + 'world'
# Out:
# 'Hello world'

# %%
'Hello ' - 'world'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 'Hello ' - 'world'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Memory

# %%
x = 7

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
x == 7
# Out:
# True

# %% [markdown]
# # ch 2 - guessed game

# %%
input()
# Out:
# 'asfd'

# %%
input()
# Out:
# '1234'

# %%
# not the same!
10 == '10'
# Out:
# False

# %%
int('10')
# Out:
# 10

# %%
10 == int('10')
# Out:
# True

# %%
if 1 == 1:
    print("ok")
else:
    print("no")
# Out:
# ok

# %% [markdown]
# ## loops

# %%
while 0 == 1:
    pass
